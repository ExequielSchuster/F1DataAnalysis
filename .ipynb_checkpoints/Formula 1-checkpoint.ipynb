# %% [markdown]
# # Formula 1 Data Analisys

# %% [markdown]
# <h3>Aca va la introduccion</h3>

# %%
import pandas as pd
import numpy as np
from IPython.display import display_html 
import matplotlib.pyplot as plt
ActualYear = 2020

# %% [markdown]
# ### Import the data

# %%
DriverDataAll = list()
DriverDataAll = [pd.read_html('https://www.formula1.com/en/results.html/'+str(i)+'/drivers.html') for i in range(1958,ActualYear)]

# %%
TeamsDataAll = list()
TeamsDataAll = [pd.read_html('https://www.formula1.com/en/results.html/'+str(i)+'/team.html') for i in range(1958,ActualYear)]

# %%
RacesRaw = list()
RacesRaw = [pd.read_html('https://www.formula1.com/en/results.html/'+str(i)+'/races.html') for i in range(1958,ActualYear)]

# %%
Years = list()
Years = [i for i in range(1958,ActualYear)]

# %%
print(TeamsDataAll[0][0].head())
print(DriverDataAll[0][0].head())
print(RacesRaw[0][0].head())
# Out:
#    Unnamed: 0  Pos           Team  PTS  Unnamed: 4
# 0         NaN    1        Vanwall   48         NaN
# 1         NaN    2        Ferrari   40         NaN
# 2         NaN    3  Cooper Climax   31         NaN
# 3         NaN    4            BRM   18         NaN
# 4         NaN    5       Maserati    6         NaN
#    Unnamed: 0  Pos               Driver Nationality            Car  PTS  \
# 0         NaN    1  Mike  Hawthorn  HAW         GBR        Ferrari   42
# 1         NaN    2  Stirling  Moss  MOS         GBR        Vanwall   41
# 2         NaN    3    Tony  Brooks  BRO         GBR        Vanwall   24
# 3         NaN    4  Roy  Salvadori  SAL         GBR  Cooper Climax   15
# 4         NaN    5  Peter  Collins  COL         GBR        Ferrari   14
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#    Unnamed: 0        Grand Prix         Date                    Winner  \
# 0         NaN         Argentina  19 Jan 1958       Stirling  Moss  MOS
# 1         NaN            Monaco  18 May 1958  Maurice Trintignant  TRI
# 2         NaN       Netherlands  26 May 1958       Stirling  Moss  MOS
# 3         NaN  Indianapolis 500  30 May 1958         Jimmy  Bryan  BRY
# 4         NaN           Belgium  15 Jun 1958         Tony  Brooks  BRO
#
#                    Car  Laps         Time  Unnamed: 7
# 0        Cooper Climax    80  2:19:33.700         NaN
# 1        Cooper Climax   100  2:52:27.900         NaN
# 2              Vanwall    75  2:04:49.200         NaN
# 3  Epperly Offenhauser   200  3:44:13.800         NaN
# 4              Vanwall    24  1:37:06.300         NaN

# %% [markdown]
# ### Save Data as .csv files

# %%
for i in range(0,ActualYear-1958): 
    DriverDataAll[i][0].to_csv(r'.\data\Drivers'+str(i+1958)+'.csv', index = False)
    TeamsDataAll[i][0].to_csv(r'.\data\Teams'+str(i+1958)+'.csv', index = False)

# %%
print(f'Total Drivers: {len(DriverDataAll)}')
print(f'Total Teams: {len(TeamsDataAll)}')
DriverDataAll[5][0].head()
# Out:
# Total Drivers: 62
# Total Teams: 62
#    Unnamed: 0  Pos                Driver Nationality             Car  PTS  \
# 0         NaN    1       Jim  Clark  CLA         GBR    Lotus Climax   54
# 1         NaN    2     Graham  Hill  HIL         GBR             BRM   29
# 2         NaN    2  Richie  Ginther  GIN         USA             BRM   29
# 3         NaN    4    John  Surtees  SUR         GBR         Ferrari   22
# 4         NaN    5      Dan  Gurney  GUR         USA  Brabham Climax   19
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# ### Number of Driver Champions and Constructors Champions

# %% [markdown]
# #### Constructors

# %%
ConstructorChampions = [TeamsDataAll[i][0].Team[0] for i in range(0,ActualYear-1958)]

UniqueTeamsChampionms = np.array(ConstructorChampions)

for team in np.unique(UniqueTeamsChampionms):
    print(team,": ", ConstructorChampions.count(team))
# Out:
# BRM :  1
# Benetton Renault :  1
# Brabham Repco :  2
# Brawn Mercedes :  1
# Cooper Climax :  2
# Ferrari :  16
# Lotus Climax :  2
# Lotus Ford :  5
# Matra Ford :  1
# McLaren Ford :  1
# McLaren Honda :  4
# McLaren Mercedes :  1
# McLaren TAG :  2
# Mercedes :  6
# RBR Renault :  1
# Red Bull Racing Renault :  3
# Renault :  2
# Tyrrell Ford :  1
# Vanwall :  1
# Williams Ford :  2
# Williams Honda :  2
# Williams Renault :  5

# %% [markdown]
# #### Drivers

# %%
DriversChampions = [DriverDataAll[i][0].Driver[0] for i in range(0,ActualYear-1958)]
uniqueDriversChampions = np.array(DriversChampions)

for driver in np.unique(uniqueDriversChampions):
    print(driver,": ", DriversChampions.count(driver))
# Out:
# Alain  Prost  PRO :  4
# Alan Jones  JON :  1
# Ayrton  Senna  SEN :  3
# Damon  Hill  HIL :  1
# Denny  Hulme  HUL :  1
# Emerson  Fittipaldi  FIT :  2
# Fernando  Alonso  ALO :  2
# Graham  Hill  HIL :  2
# Jack  Brabham  BRA :  3
# Jackie  Stewart  STE :  3
# Jacques  Villeneuve  VIL :  1
# James  Hunt  HUN :  1
# Jenson  Button  BUT :  1
# Jim  Clark  CLA :  2
# Jochen  Rindt  RIN :  1
# Jody  Scheckter  SCH :  1
# John  Surtees  SUR :  1
# Keke  Rosberg  ROS :  1
# Kimi  Räikkönen  RAI :  1
# Lewis  Hamilton  HAM :  6
# Mario  Andretti  AND :  1
# Michael  Schumacher  MSC :  7
# Mika  Hakkinen  HAK :  2
# Mike  Hawthorn  HAW :  1
# Nelson  Piquet  PIQ :  3
# Nico  Rosberg  ROS :  1
# Nigel  Mansell  MAN :  1
# Niki  Lauda  LAU :  3
# Phil  Hill  HIL :  1
# Sebastian  Vettel  VET :  4
# ['Mike  Hawthorn  HAW',
#  'Jack  Brabham  BRA',
#  'Jack  Brabham  BRA',
#  'Phil  Hill  HIL',
#  'Graham  Hill  HIL',
#  'Jim  Clark  CLA',
#  'John  Surtees  SUR',
#  'Jim  Clark  CLA',
#  'Jack  Brabham  BRA',
#  'Denny  Hulme  HUL',
#  'Graham  Hill  HIL',
#  'Jackie  Stewart  STE',
#  'Jochen  Rindt  RIN',
#  'Jackie  Stewart  STE',
#  'Emerson  Fittipaldi  FIT',
#  'Jackie  Stewart  STE',
#  'Emerson  Fittipaldi  FIT',
#  'Niki  Lauda  LAU',
#  'James  Hunt  HUN',
#  'Niki  Lauda  LAU',
#  'Mario  Andretti  AND',
#  'Jody  Scheckter  SCH',
#  'Alan Jones  JON',
#  'Nelson  Piquet  PIQ',
#  'Keke  Rosberg  ROS',
#  'Nelson  Piquet  PIQ',
#  'Niki  Lauda  LAU',
#  'Alain  Prost  PRO',
#  'Alain  Prost  PRO',
#  'Nelson  Piquet  PIQ',
#  'Ayrton  Senna  SEN',
#  'Alain  Prost  PRO',
#  'Ayrton  Senna  SEN',
#  'Ayrton  Senna  SEN',
#  'Nigel  Mansell  MAN',
#  'Alain  Prost  PRO',
#  'Michael  Schumacher  MSC',
#  'Michael  Schumacher  MSC',
#  'Damon  Hill  HIL',
#  'Jacques  Villeneuve  VIL',
#  'Mika  Hakkinen  HAK',
#  'Mika  Hakkinen  HAK',
#  'Michael  Schumacher  MSC',
#  'Michael  Schumacher  MSC',
#  'Michael  Schumacher  MSC',
#  'Michael  Schumacher  MSC',
#  'Michael  Schumacher  MSC',
#  'Fernando  Alonso  ALO',
#  'Fernando  Alonso  ALO',
#  'Kimi  Räikkönen  RAI',
#  'Lewis  Hamilton  HAM',
#  'Jenson  Button  BUT',
#  'Sebastian  Vettel  VET',
#  'Sebastian  Vettel  VET',
#  'Sebastian  Vettel  VET',
#  'Sebastian  Vettel  VET',
#  'Lewis  Hamilton  HAM',
#  'Lewis  Hamilton  HAM',
#  'Nico  Rosberg  ROS',
#  'Lewis  Hamilton  HAM',
#  'Lewis  Hamilton  HAM',
#  'Lewis  Hamilton  HAM']

# %% [markdown]
# ### All

# %% [markdown]
# #### Drivers

# %%
Drivers1and2Diff = [DriverDataAll[i][0].PTS[0]-DriverDataAll[i][0].PTS[1] for i in range(0,ActualYear-1958)] 
Drivers1and3Diff = [DriverDataAll[i][0].PTS[0]-DriverDataAll[i][0].PTS[2] for i in range(0,ActualYear-1958)]

# %%
plt.plot(Years,Drivers1and2Diff)
plt.plot(Years,Drivers1and3Diff)
plt.suptitle('Drivers Championship Points Difference')
plt.xlabel("Year")
plt.ylabel("Points")
#plt.show()
plt.legend(["1 and 2 Diff", "1 and 3 Diff"])

# %%
Drivers1and2DiffPerc = [(Drivers1and2Diff[i]/DriverDataAll[i][0].PTS[1])*100 for i in range(0,ActualYear-1958)] 
Drivers1and3DiffPerc = [(Drivers1and3Diff[i]/DriverDataAll[i][0].PTS[2])*100 for i in range(0,ActualYear-1958)]

# %%
plt.plot(Years,Drivers1and2DiffPerc)
plt.plot(Years,Drivers1and3DiffPerc)
plt.suptitle('Drivers Championship Points Difference %')
plt.xlabel("Year")
plt.ylabel("%")
plt.legend(["1 and 2 Diff", "1 and 3 Diff"])

# %% [markdown]
# #### Constructors

# %%
Teams1and2Diff = [TeamsDataAll[i][0].PTS[0]-TeamsDataAll[i][0].PTS[1] for i in range(0,ActualYear-1958)] 
Teams1and3Diff = [TeamsDataAll[i][0].PTS[0]-TeamsDataAll[i][0].PTS[2] for i in range(0,ActualYear-1958)]

# %%
plt.plot(Years,Teams1and2Diff)
plt.plot(Years,Teams1and3Diff)
plt.suptitle('Constructors Championship Points Difference')
plt.xlabel("Year")
plt.ylabel("Points")
plt.legend(["1 and 2 Diff", "1 and 3 Diff"])

# %%
Teams1and2DiffPerc = [(Teams1and2Diff[i]/TeamsDataAll[i][0].PTS[1])*100 for i in range(0,ActualYear-1958)] 
Teams1and3DiffPerc = [(Teams1and3Diff[i]/TeamsDataAll[i][0].PTS[2])*100 for i in range(0,ActualYear-1958)]

# %%
plt.plot(Years,Teams1and2DiffPerc)
plt.suptitle('Constructor Championship Points Difference %')
plt.xlabel("Year")
plt.ylabel("%")
plt.plot(Years,Teams1and3DiffPerc)
plt.legend(["1 and 2 Diff", "1 and 3 Diff"])

# %%
#from datetime import timedelta
#for year in range(0,ActualYear-1958):
#    TimeYear = [RacesRaw[year][0].Time[time] for time in range(0,RacesRaw[year][0].shape[0])]
#    print(TimeYear[0])
#    str(timedelta(seconds=sum(map(lambda f: int(f[0])*3600 + int(f[1])*60 + int(f[2]) + int(f[3])/1000, map(lambda f: f.split(':'), TimeYear)))/len(TimeYear)))

# %%
RacesCount = [RacesRaw[i][0].shape[0] for i in range(0,ActualYear-1958)]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.bar(Years,RacesCount)
plt.show()

# %% [markdown]
# ### WDR Wins per year

# %%
year = 0
count = 0
RacesWinChampions = list()
for driver in DriversChampions:
    for race in RacesRaw[year][0].Winner:
        if driver==race:
            count=count+1
    year=year+1
    RacesWinChampions.append(count)
    count=0

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.bar(Years,RacesWinChampions)
plt.show()

# %%
RacesWinChampionsPerc = list()
RacesWinChampionsPerc = [(RacesWinChampions[year]/RacesCount[year])*100 for year in range(0,len(Years))]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.bar(Years,RacesWinChampionsPerc)
plt.show()
